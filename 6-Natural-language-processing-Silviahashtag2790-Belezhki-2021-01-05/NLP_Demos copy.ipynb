# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, SimpleRNN, GRU, LSTM, Bidirectional, Embedding

# %%
rnn = Sequential([
    Input((10, 4)),
    SimpleRNN(64, activation  = "relu")
])

# %%
rnn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_2 (SimpleRNN)    (None, 64)                4416
#
# =================================================================
# Total params: 4,416
# Trainable params: 4,416
# Non-trainable params: 0
# _________________________________________________________________

# %%
rnn2 = Sequential([
    Input((10, 4)),
    SimpleRNN(64, activation  = "relu", return_sequences = True),
    SimpleRNN(32, activation  = "relu", return_sequences = True),
    SimpleRNN(16, activation  = "relu", return_sequences = True),
    SimpleRNN(8, activation  = "relu")
])

# %%
rnn2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_10 (SimpleRNN)   (None, 10, 64)            4416
#
#  simple_rnn_11 (SimpleRNN)   (None, 10, 32)            3104
#
#  simple_rnn_12 (SimpleRNN)   (None, 10, 16)            784
#
#  simple_rnn_13 (SimpleRNN)   (None, 8)                 200
#
# =================================================================
# Total params: 8,504
# Trainable params: 8,504
# Non-trainable params: 0
# _________________________________________________________________

# %%
rnn3_layer1 = SimpleRNN(64, return_sequences = True, return_state = True)

# %%
data = np.random.normal(size = (16, 10, 4))
# steps, variables,

# %%
rnn3_layer1(data)
# Out:
# [<tf.Tensor: shape=(16, 10, 64), dtype=float32, numpy=
#  array([[[-0.06532398, -0.05810557,  0.19030093, ..., -0.01456565,
#            0.03920301,  0.4835705 ],
#          [ 0.5687352 , -0.30775076,  0.17016338, ...,  0.30640963,
#           -0.70588493, -0.46529058],
#          [-0.02913049,  0.7201563 ,  0.64132524, ..., -0.58490825,
#           -0.41690785,  0.3156782 ],
#          ...,
#          [-0.6847788 ,  0.04005945,  0.6918271 , ..., -0.7526107 ,
#           -0.33546674, -0.7507666 ],
#          [-0.7990683 , -0.44692868, -0.21341692, ...,  0.10901958,
#            0.7562435 ,  0.38238305],
#          [-0.04290424, -0.08277518,  0.4126016 , ..., -0.01137064,
#            0.33054623,  0.25747448]],
#
#         [[-0.11057088, -0.13304606,  0.12079915, ..., -0.00432236,
#           -0.08912548,  0.135906  ],
#          [ 0.8807096 , -0.14831896, -0.2955724 , ...,  0.5497358 ,
#           -0.0330222 , -0.2767284 ],
#          [ 0.595951  , -0.4590593 ,  0.4510797 , ..., -0.45476374,
#           -0.6547944 , -0.46778032],
#          ...,
#          [-0.4236308 , -0.04255453,  0.44466102, ..., -0.53264016,
#           -0.45346493, -0.68768585],
#          [ 0.11057673, -0.16301227,  0.8005892 , ..., -0.08424442,
#           -0.91994435, -0.78600365],
#          [ 0.24816999, -0.6366587 , -0.46695915, ..., -0.04128026,
#            0.6870046 , -0.02084881]],
#
#         [[ 0.18680929, -0.10821073, -0.29193842, ...,  0.01391782,
#            0.3305874 ,  0.4460814 ],
#          [ 0.5935729 , -0.2535986 ,  0.31471905, ...,  0.427204  ,
#           -0.7769381 , -0.83474416],
#          [-0.28161156,  0.5584806 ,  0.669806  , ..., -0.47243875,
#           -0.6413879 ,  0.6585571 ],
#          ...,
#          [-0.57982945, -0.02419651, -0.30350372, ...,  0.09546182,
#           -0.7313916 , -0.3620811 ],
#          [-0.9726906 ,  0.06245674, -0.5008775 , ..., -0.83241534,
#            0.5136702 ,  0.7449199 ],
#          [-0.8068747 ,  0.02309154,  0.20344025, ..., -0.5579185 ,
#            0.8570559 ,  0.10545465]],
#
#         ...,
#
#         [[-0.0469837 , -0.2962639 ,  0.03237771, ...,  0.06343801,
#           -0.12935494,  0.05071796],
#          [ 0.0017302 , -0.05540578,  0.44266903, ..., -0.21184328,
#           -0.08688405,  0.5595437 ],
#          [ 0.5012218 ,  0.65174437,  0.3618907 , ..., -0.389068  ,
#           -0.00539396,  0.59766513],
#          ...,
#          [ 0.7388814 ,  0.3145899 , -0.40664002, ..., -0.28058642,
#           -0.24415296,  0.2118559 ],
#          [-0.62474465,  0.20615053, -0.20468655, ..., -0.42050582,
#            0.67630637,  0.42700905],
#          [ 0.35091877,  0.2970928 , -0.553025  , ...,  0.4669078 ,
#            0.13289604, -0.47315165]],
#
#         [[-0.3491552 ,  0.26239297,  0.31915727, ..., -0.22683585,
#            0.04213625,  0.41373938],
#          [-0.02912618, -0.00462961,  0.14204168, ...,  0.3112972 ,
#           -0.37712982,  0.27565324],
#          [-0.16364874,  0.03552198,  0.30224466, ..., -0.36362475,
#           -0.38371748,  0.5396482 ],
#          ...,
#          [-0.25131893,  0.6328814 , -0.27935958, ...,  0.11272265,
#            0.5340452 ,  0.8000466 ],
#          [ 0.2758228 ,  0.43114138, -0.37895337, ...,  0.04362011,
#           -0.10837846, -0.59521294],
#          [-0.68184984, -0.16280583, -0.31846172, ..., -0.5188217 ,
#           -0.47332627,  0.0155658 ]],
#
#         [[ 0.49740097,  0.1754741 ,  0.07550281, ...,  0.3338444 ,
#           -0.24926434, -0.6420436 ],
#          [ 0.04943529, -0.2745316 ,  0.5918633 , ...,  0.06549078,
#           -0.53660434, -0.624181  ],
#          [ 0.6029711 , -0.33362037,  0.071878  , ...,  0.4582903 ,
#            0.48653582, -0.2645659 ],
#          ...,
#          [-0.57376057, -0.54693496, -0.87397933, ..., -0.2906024 ,
#            0.3317592 ,  0.5610959 ],
#          [-0.54280466, -0.7117066 , -0.45389998, ...,  0.01115871,
#           -0.36733633, -0.01133086],
#          [-0.04239992,  0.17047274, -0.11125173, ...,  0.0627894 ,
#           -0.8739759 ,  0.03321528]]], dtype=float32)>,
#  <tf.Tensor: shape=(16, 64), dtype=float32, numpy=
#  array([[-0.04290424, -0.08277518,  0.4126016 , ..., -0.01137064,
#           0.33054623,  0.25747448],
#         [ 0.24816999, -0.6366587 , -0.46695915, ..., -0.04128026,
#           0.6870046 , -0.02084881],
#         [-0.8068747 ,  0.02309154,  0.20344025, ..., -0.5579185 ,
#           0.8570559 ,  0.10545465],
#         ...,
#         [ 0.35091877,  0.2970928 , -0.553025  , ...,  0.4669078 ,
#           0.13289604, -0.47315165],
#         [-0.68184984, -0.16280583, -0.31846172, ..., -0.5188217 ,
#          -0.47332627,  0.0155658 ],
#         [-0.04239992,  0.17047274, -0.11125173, ...,  0.0627894 ,
#          -0.8739759 ,  0.03321528]], dtype=float32)>]

# %%
x = np.random.normal(size = (16, 10, 4))
# batch size, time steps, variables

# %%
rnn2.predict(x)
# Out:
# array([[0.3401082 , 0.22542737, 0.08438864, 0.16208813, 0.        ,
#         0.5166507 , 0.        , 0.1268729 ],
#        [0.        , 0.1375774 , 0.4630014 , 0.41140172, 0.        ,
#         0.22481415, 0.        , 0.        ],
#        [0.5441092 , 0.        , 1.0274831 , 0.82794803, 0.        ,
#         0.        , 0.        , 0.2869411 ],
#        [0.62194526, 0.08886561, 0.03928444, 0.10085015, 0.        ,
#         0.05448556, 0.        , 0.4482446 ],
#        [0.1388034 , 0.01088637, 0.11562759, 0.14251307, 0.        ,
#         0.7267194 , 0.        , 0.        ],
#        [0.10961133, 0.1940727 , 0.2951361 , 0.38154066, 0.        ,
#         0.2690384 , 0.11290035, 0.36766946],
#        [0.2674029 , 0.        , 0.2095564 , 0.30517784, 0.        ,
#         0.36903244, 0.        , 0.25840703],
#        [0.7165885 , 0.5639709 , 0.6609867 , 0.17306194, 0.        ,
#         0.27882466, 0.        , 0.47619474],
#        [0.29646912, 0.        , 0.16834001, 0.59909153, 0.11998962,
#         0.08220971, 0.        , 0.44985074],
#        [0.980034  , 0.1625196 , 0.7994296 , 0.04653357, 0.        ,
#         0.        , 0.0483356 , 0.46302742],
#        [0.7549521 , 0.14278877, 0.3887905 , 0.19463113, 0.        ,
#         0.        , 0.        , 0.02299064],
#        [0.        , 0.34144643, 0.07948276, 0.5005667 , 0.        ,
#         0.14592427, 0.22712019, 0.31904897],
#        [0.7015805 , 0.02631053, 0.41001993, 0.6174608 , 0.19276644,
#         0.        , 0.        , 0.29160684],
#        [0.2130547 , 0.12701389, 0.        , 0.0109125 , 0.        ,
#         0.        , 0.        , 0.        ],
#        [0.5677527 , 0.        , 0.5576822 , 0.3279447 , 0.        ,
#         0.57927716, 0.        , 0.36682117],
#        [0.70533943, 0.49800307, 0.        , 0.        , 0.        ,
#         0.2742038 , 0.        , 0.51329887]], dtype=float32)

# %%
rnn2.predict(x).shape
# Out:
# (16, 8)

# %%
rnn2.predict(x)[0] # first sample
# Out:
# array([0.3401082 , 0.22542737, 0.08438864, 0.16208813, 0.        ,
#        0.5166507 , 0.        , 0.1268729 ], dtype=float32)

# %%
gru = GRU(64, return_sequences = True, return_state = True)

# %%
gru(x)
# Out:
# [<tf.Tensor: shape=(16, 10, 64), dtype=float32, numpy=
#  array([[[-0.00213465, -0.01808017, -0.02695779, ...,  0.02834189,
#            0.01589131,  0.06356727],
#          [ 0.00029919, -0.02640589,  0.04205329, ..., -0.00828133,
#           -0.00336965, -0.01011924],
#          [-0.1006368 ,  0.14039205, -0.04183628, ...,  0.02938236,
#           -0.03895453, -0.06474994],
#          ...,
#          [ 0.01957642, -0.00103381, -0.03736681, ..., -0.1348305 ,
#           -0.03373634, -0.11756691],
#          [-0.17514157,  0.16779903,  0.01467467, ...,  0.20657718,
#           -0.07210222, -0.022672  ],
#          [-0.07387082, -0.10175827,  0.0479712 , ..., -0.10149594,
#           -0.02401397, -0.14532544]],
#
#         [[-0.02222935,  0.12487374, -0.13863146, ...,  0.10914349,
#            0.0166954 ,  0.17174782],
#          [ 0.02296122,  0.11231555, -0.10230935, ..., -0.0040185 ,
#            0.00789654,  0.03505372],
#          [-0.01050266,  0.00199502,  0.06813346, ...,  0.02070378,
#           -0.01014769, -0.05586004],
#          ...,
#          [-0.06153521, -0.01072399, -0.06437486, ...,  0.03085239,
#            0.03956139, -0.01190462],
#          [-0.00859392, -0.11080138,  0.03277211, ...,  0.10106014,
#            0.05288517,  0.13507982],
#          [-0.1010931 ,  0.11289579,  0.02875132, ...,  0.14863689,
#           -0.02131057,  0.03964195]],
#
#         [[-0.07562807,  0.17029074, -0.07340018, ...,  0.14833832,
#           -0.01091144,  0.11047018],
#          [-0.00683091,  0.09111858, -0.07348561, ...,  0.06053204,
#            0.02040469,  0.06174206],
#          [ 0.11372815,  0.09464169, -0.03754306, ..., -0.12049779,
#           -0.01416377, -0.08979739],
#          ...,
#          [-0.0980106 , -0.13225023,  0.06825242, ..., -0.08371794,
#           -0.03781622, -0.09459061],
#          [-0.07268284, -0.14163086, -0.09518486, ..., -0.13080576,
#           -0.01072234, -0.02044347],
#          [-0.04098824, -0.04875563, -0.06378323, ..., -0.07731096,
#           -0.02499691,  0.00840365]],
#
#         ...,
#
#         [[-0.15536   ,  0.20929307, -0.03999736, ...,  0.06422931,
#           -0.05462744, -0.10402939],
#          [-0.10412078, -0.04978823,  0.00153244, ...,  0.02655845,
#            0.01314991, -0.02218717],
#          [-0.06789537, -0.17813058,  0.06620971, ...,  0.02306891,
#            0.02661395,  0.04386816],
#          ...,
#          [-0.04534157,  0.12401141, -0.06947021, ..., -0.08380974,
#           -0.04981809, -0.07024997],
#          [-0.07534827,  0.06779113, -0.03885853, ...,  0.0027937 ,
#           -0.03603831, -0.04562951],
#          [-0.13738388,  0.08582842, -0.03548202, ...,  0.09518869,
#           -0.03521802, -0.01668913]],
#
#         [[ 0.05966223, -0.13272315,  0.10294538, ..., -0.05849051,
#            0.01793803, -0.01437634],
#          [-0.06679972, -0.04128384,  0.09373377, ...,  0.05434943,
#           -0.02429255, -0.02014068],
#          [-0.15388462,  0.10690306, -0.02431345, ...,  0.09359304,
#           -0.03957542, -0.01680502],
#          ...,
#          [ 0.03151304, -0.12555528,  0.19972378, ...,  0.04202915,
#            0.02978947,  0.02740455],
#          [ 0.03141703,  0.10539545,  0.07611515, ..., -0.15826613,
#           -0.07123486, -0.19404857],
#          [-0.02686096,  0.15476377,  0.05123171, ...,  0.02150529,
#           -0.06014632, -0.09561134]],
#
#         [[ 0.03339443,  0.00884159,  0.02819771, ..., -0.05335833,
#           -0.0128153 , -0.05891216],
#          [ 0.11416022, -0.15049684,  0.22143084, ..., -0.05142484,
#            0.00653258, -0.04592084],
#          [ 0.08666954, -0.02445053,  0.18603542, ...,  0.03475427,
#           -0.02296326,  0.01481822],
#          ...,
#          [-0.21025185, -0.01131952,  0.10443598, ...,  0.10938179,
#           -0.07010668, -0.13905057],
#          [-0.13964024,  0.04606641, -0.036265  , ...,  0.03148953,
#           -0.04009396, -0.07103951],
#          [-0.07576618,  0.17149453, -0.14259754, ...,  0.00123566,
#           -0.03649163, -0.0646216 ]]], dtype=float32)>,
#  <tf.Tensor: shape=(16, 64), dtype=float32, numpy=
#  array([[-0.07387082, -0.10175827,  0.0479712 , ..., -0.10149594,
#          -0.02401397, -0.14532544],
#         [-0.1010931 ,  0.11289579,  0.02875132, ...,  0.14863689,
#          -0.02131057,  0.03964195],
#         [-0.04098824, -0.04875563, -0.06378323, ..., -0.07731096,
#          -0.02499691,  0.00840365],
#         ...,
#         [-0.13738388,  0.08582842, -0.03548202, ...,  0.09518869,
#          -0.03521802, -0.01668913],
#         [-0.02686096,  0.15476377,  0.05123171, ...,  0.02150529,
#          -0.06014632, -0.09561134],
#         [-0.07576618,  0.17149453, -0.14259754, ...,  0.00123566,
#          -0.03649163, -0.0646216 ]], dtype=float32)>]

# %%
lstm = LSTM(64, return_sequences = True, return_state = True)

# %%
lstm(x)
# Out:
# [<tf.Tensor: shape=(16, 10, 64), dtype=float32, numpy=
#  array([[[-0.00808366, -0.02491725,  0.01294041, ..., -0.01085905,
#           -0.00889657, -0.00310304],
#          [ 0.00032295,  0.01016319,  0.01126023, ...,  0.01329921,
#           -0.00157602, -0.00947394],
#          [ 0.03607395,  0.03539491, -0.05384002, ..., -0.04399928,
#           -0.02338282,  0.03871839],
#          ...,
#          [ 0.00559593,  0.01230644, -0.00686457, ...,  0.05222547,
#            0.03697014,  0.01938259],
#          [ 0.09103241,  0.08238864, -0.06892659, ..., -0.03087617,
#           -0.0518513 ,  0.04465212],
#          [ 0.0915408 ,  0.10459499, -0.00609464, ...,  0.04235046,
#           -0.0038656 ,  0.00695703]],
#
#         [[-0.02131006, -0.07732373, -0.02711751, ..., -0.09263879,
#           -0.02001886,  0.03113827],
#          [-0.0367116 , -0.07450332, -0.03901041, ..., -0.05772586,
#            0.00617182,  0.04887157],
#          [ 0.0097407 ,  0.02230897, -0.02217905, ..., -0.0022341 ,
#           -0.00926121,  0.01391745],
#          ...,
#          [ 0.06078615,  0.01132944, -0.03309188, ..., -0.03317282,
#           -0.01784001,  0.05549497],
#          [ 0.03271672, -0.01382655,  0.04324908, ..., -0.00709496,
#           -0.02192189, -0.00936903],
#          [ 0.06098089,  0.0322026 , -0.0307954 , ..., -0.06256431,
#           -0.04057266,  0.03723494]],
#
#         [[ 0.00976584, -0.03195007, -0.05061569, ..., -0.09195776,
#           -0.03121461,  0.03945037],
#          [-0.01135899, -0.05276713, -0.03392544, ..., -0.06661963,
#           -0.01569487,  0.04135904],
#          [-0.03721193, -0.02241489, -0.04726582, ...,  0.0062367 ,
#            0.06601118,  0.04664398],
#          ...,
#          [ 0.09520432,  0.09486631,  0.05040359, ...,  0.04349202,
#           -0.01764925, -0.03189988],
#          [ 0.05701572,  0.02244343,  0.065134  , ...,  0.04175643,
#            0.00244673, -0.03694104],
#          [ 0.04227514, -0.00203489,  0.04846804, ...,  0.04007939,
#            0.01162433, -0.02232441]],
#
#         ...,
#
#         [[ 0.06242285,  0.06989916, -0.08533712, ..., -0.06253539,
#           -0.03370661,  0.05718685],
#          [ 0.05882732,  0.04793036, -0.00110727, ..., -0.01115519,
#           -0.03563991,  0.01201105],
#          [ 0.05196315,  0.03791984,  0.06814092, ...,  0.02251659,
#           -0.03168897, -0.04000555],
#          ...,
#          [ 0.0252138 ,  0.00605359,  0.00275408, ...,  0.02248077,
#            0.02533549,  0.00158219],
#          [ 0.04825497,  0.02841945, -0.00328347, ...,  0.01026892,
#           -0.00333173,  0.01279546],
#          [ 0.07703847,  0.04471724, -0.02549128, ..., -0.02413075,
#           -0.03838103,  0.03359808]],
#
#         [[-0.01479337,  0.01424938,  0.05018235, ...,  0.05182995,
#            0.02828866, -0.05768372],
#          [ 0.03893409,  0.06627099,  0.01707226, ...,  0.01069972,
#           -0.0301341 , -0.0206832 ],
#          [ 0.06198041,  0.05433783, -0.04207418, ..., -0.06139043,
#           -0.04786618,  0.02404324],
#          ...,
#          [ 0.00572411,  0.03174838,  0.06767878, ...,  0.02684378,
#           -0.00786647, -0.06613921],
#          [ 0.02126138,  0.12879676, -0.01796866, ...,  0.04579821,
#            0.0494678 , -0.01658991],
#          [ 0.04387716,  0.10614005, -0.03983837, ..., -0.01304799,
#            0.0114024 ,  0.00876281]],
#
#         [[-0.00391164,  0.01832756, -0.0068936 , ...,  0.0212505 ,
#            0.02376092, -0.00345021],
#          [-0.01448368,  0.05298233,  0.05812661, ...,  0.06860397,
#            0.05548337, -0.09550155],
#          [-0.01033722,  0.05149454,  0.02469965, ...,  0.0237432 ,
#            0.01890309, -0.05481868],
#          ...,
#          [ 0.11029519,  0.1708072 ,  0.00017591, ..., -0.0011629 ,
#           -0.07893389, -0.01751557],
#          [ 0.07481832,  0.07112817, -0.01423085, ..., -0.02686558,
#           -0.03375868, -0.00031233],
#          [ 0.04534126,  0.01219015, -0.05201062, ..., -0.06061095,
#            0.00126829,  0.04069774]]], dtype=float32)>,
#  <tf.Tensor: shape=(16, 64), dtype=float32, numpy=
#  array([[ 0.0915408 ,  0.10459499, -0.00609464, ...,  0.04235046,
#          -0.0038656 ,  0.00695703],
#         [ 0.06098089,  0.0322026 , -0.0307954 , ..., -0.06256431,
#          -0.04057266,  0.03723494],
#         [ 0.04227514, -0.00203489,  0.04846804, ...,  0.04007939,
#           0.01162433, -0.02232441],
#         ...,
#         [ 0.07703847,  0.04471724, -0.02549128, ..., -0.02413075,
#          -0.03838103,  0.03359808],
#         [ 0.04387716,  0.10614005, -0.03983837, ..., -0.01304799,
#           0.0114024 ,  0.00876281],
#         [ 0.04534126,  0.01219015, -0.05201062, ..., -0.06061095,
#           0.00126829,  0.04069774]], dtype=float32)>,
#  <tf.Tensor: shape=(16, 64), dtype=float32, numpy=
#  array([[ 0.16759534,  0.19121349, -0.01136488, ...,  0.07865044,
#          -0.00621748,  0.01095296],
#         [ 0.12400706,  0.06226352, -0.06526874, ..., -0.12737302,
#          -0.0935766 ,  0.09476041],
#         [ 0.08391759, -0.00413112,  0.09825658, ...,  0.08365776,
#           0.02285372, -0.04357488],
#         ...,
#         [ 0.16381924,  0.08872792, -0.05002094, ..., -0.04820799,
#          -0.08210746,  0.07396496],
#         [ 0.08903661,  0.21878555, -0.08127636, ..., -0.02763721,
#           0.02394365,  0.01957655],
#         [ 0.09116116,  0.02528585, -0.10996267, ..., -0.1136905 ,
#           0.0027004 ,  0.07932419]], dtype=float32)>]

# %%
lstm.weights[0].shape
# Out:
# TensorShape([4, 256])

# %%
bidirectional = Bidirectional(LSTM(64))

# %%
bidirectional(x)
# Out:
# <tf.Tensor: shape=(16, 128), dtype=float32, numpy=
# array([[ 0.00817883,  0.05050353,  0.09217387, ...,  0.00589207,
#         -0.06511257,  0.01136211],
#        [-0.03545505, -0.01065368, -0.04280177, ...,  0.0344828 ,
#         -0.12822144,  0.068075  ],
#        [ 0.03502763,  0.06504878,  0.02121772, ...,  0.0198219 ,
#         -0.10812231,  0.0308398 ],
#        ...,
#        [ 0.01725266, -0.00031984,  0.01206602, ..., -0.06697213,
#         -0.01746143, -0.05275025],
#        [-0.0648874 , -0.01378255,  0.10647972, ..., -0.03881293,
#          0.03185516, -0.06036908],
#        [-0.02082562,  0.00679044,  0.00145065, ...,  0.02659761,
#          0.03627623, -0.009247  ]], dtype=float32)>

# %%
lstm_with_embedding = Sequential([
    Embedding(10000, 400),
    LSTM(64)
])

# %%
lstm_with_embedding.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 400)         4000000
#
#  lstm_2 (LSTM)               (None, 64)                119040
#
# =================================================================
# Total params: 4,119,040
# Trainable params: 4,119,040
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.preprocessing.text.Tokenizer()
